# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from lib import load_curvecurator, fit, plot_fit, to_p_space, from_p_space

# %%
drug = {
    'identifier': "10184653/2reps_only",
    'target_ec50_nm': 3,
}

df_curvecurator, df_doses = load_curvecurator(drug['identifier'])
target_pec50 = to_p_space(drug['target_ec50_nm'] / 1e9)
target_pec50_range = np.array([target_pec50 - 0.5, target_pec50 + 0.5])
target_ec50_range = from_p_space(target_pec50_range)

# %%
cell_line = "CVCL_3117"
cell_line = "CVCL_L083"

# %%
df_curvecurator = fit(df_curvecurator, df_doses, target_pec50_range)

# %%
plot_fit(df_curvecurator, df_doses, cell_line, target_ec50_range)
plt.show()
plt.close()
